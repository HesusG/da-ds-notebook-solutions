# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HesusG/da-ds-notebook-solutions/blob/assesment-criteria/LATAM%20V7%20DADS/9-18%20DS/SP17%20Computer%20Vision/P%20Spanish%20version/S17%20ESP%20SOL3%20Vision%20artificial%20-%20Colab%20GPU.ipynb)

# %% [markdown]
# # Visión Artificial para Determinar la Edad
#
# ## ¿Por qué este proyecto es diferente?
#
# Hasta ahora en el bootcamp hemos trabajado con **datos tabulares** (CSVs con filas y columnas). Este proyecto es diferente: trabajamos con **imágenes**.
#
# Para procesar imágenes usamos **Redes Neuronales Convolucionales (CNNs)**, un tipo de arquitectura de deep learning diseñada específicamente para detectar patrones visuales como bordes, texturas y formas.
#
# ```
# DATOS TABULARES                    IMÁGENES
# ┌────────────────────┐             ┌────────────────────┐
# │ edad │ salario │...│             │ ░░▓▓░░▓▓░░▓▓░░▓▓░░ │
# ├────────────────────┤             │ ░░▓▓░░▓▓░░▓▓░░▓▓░░ │
# │  25  │  50000  │...│             │ ▓▓░░▓▓░░▓▓░░▓▓░░▓▓ │
# │  32  │  65000  │...│     →       │ ▓▓░░▓▓░░▓▓░░▓▓░░▓▓ │
# │  45  │  80000  │...│             │ ░░▓▓░░▓▓░░▓▓░░▓▓░░ │
# └────────────────────┘             └────────────────────┘
#     Modelos clásicos                      CNNs
#   (Random Forest, etc.)              (ResNet, VGG, etc.)
# ```
#
# El problema: las CNNs requieren **millones de cálculos matemáticos** por cada imagen. Tu computadora normal (CPU) no está optimizada para esto.

# %% [markdown]
# ---
#
# ## ¿Qué es un CPU?
#
# El **CPU (Central Processing Unit)** es el "cerebro" de tu computadora. Es muy bueno para:
#
# - Ejecutar programas
# - Procesar texto y hojas de cálculo
# - Tareas que requieren decisiones complejas
#
# ```
# CPU: Pocos núcleos muy potentes (4-16 típicamente)
#
# ┌─────────────────────────────────────┐
# │  ┌─────┐  ┌─────┐  ┌─────┐  ┌─────┐│
# │  │CORE │  │CORE │  │CORE │  │CORE ││
# │  │  1  │  │  2  │  │  3  │  │  4  ││
# │  └─────┘  └─────┘  └─────┘  └─────┘│
# │         Cada núcleo es MUY          │
# │         potente pero hay pocos      │
# └─────────────────────────────────────┘
#
# Analogía: Un chef experto que cocina platos complejos,
#           uno a la vez, con alta calidad.
# ```
#
# **Problema con imágenes:** Procesar UNA imagen de 224x224 píxeles implica ~150,000 valores. Con millones de operaciones matemáticas, el CPU tarda horas.

# %% [markdown]
# ---
#
# ## ¿Qué es un GPU?
#
# El **GPU (Graphics Processing Unit)** fue creado originalmente para **videojuegos**. Los juegos necesitan calcular millones de píxeles 60 veces por segundo para renderizar gráficos 3D.
#
# ```
# GPU: Miles de núcleos pequeños (2,000-10,000+)
#
# ┌─────────────────────────────────────────────────────┐
# │ ┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐  │
# │ └─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘  │
# │ ┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐  │
# │ └─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘  │
# │ ┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐┌─┐  │
# │ └─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘└─┘  │
# │        Muchos núcleos pequeños trabajando         │
# │              EN PARALELO                          │
# └─────────────────────────────────────────────────────┘
#
# Analogía: 1,000 ayudantes de cocina. Cada uno solo sabe
#           cortar verduras, pero juntos preparan 1,000
#           ensaladas en el tiempo que el chef hace una.
# ```
#
# ### De videojuegos a Inteligencia Artificial
#
# Los investigadores descubrieron que las operaciones matemáticas de los videojuegos (multiplicar matrices, procesar píxeles en paralelo) son **exactamente las mismas** que necesitan las redes neuronales.
#
# ```
# LÍNEA DE TIEMPO GPU
#
# 1999 ──── 2007 ──── 2012 ──── 2020 ──── Hoy
#   │         │         │         │         │
#   │         │         │         │         │
# GeForce   CUDA     AlexNet   GPT-3    ChatGPT
# (juegos)  (NVIDIA  (CNN que   (IA      (IA
#           programa  gana      masiva)  conversacional)
#           GPUs)    ImageNet)
# ```
#
# Hoy, los GPUs son esenciales para:
# - **Deep Learning / IA** (este proyecto)
# - Computación científica
# - Criptografía
# - Simulaciones físicas

# %% [markdown]
# ---
#
# ## Comparación de tiempos: CPU vs GPU
#
# Para este proyecto (7,591 imágenes, ResNet50, 20 épocas):
#
# ```
# ┌────────────────────────────────────────────────────┐
# │                  TIEMPO DE ENTRENAMIENTO           │
# ├────────────────────────────────────────────────────┤
# │                                                    │
# │  CPU (tu laptop):     ████████████████████████████ │
# │                       10-20 HORAS                  │
# │                                                    │
# │  GPU (Google Colab):  ██                           │
# │                       ~20-25 MINUTOS               │
# │                                                    │
# └────────────────────────────────────────────────────┘
#
# La GPU es aproximadamente 30-50x más rápida para CNNs.
# ```
#
# Por esto, **el entrenamiento del modelo debe ejecutarse en Google Colab** (GPU gratuita), no en la plataforma de TripleTen.

# %% [markdown]
# ---
#
# ## Cómo Activar la GPU en Google Colab
#
# Ahora que entendemos por qué necesitamos una GPU, vamos a configurarla en Google Colab. Por defecto, Colab asigna solo CPU. Debemos cambiar esto manualmente.
#
# ### Paso a Paso
#
# **Paso 1:** Haz clic en el botón **"Connect"** (Conectar) en la esquina superior derecha del notebook.
#
# ```
# ┌────────────────────────────────────────────────────────────┐
# │  File  Edit  View  Insert  Runtime  Tools  Help           │
# │                                          ┌─────────────┐  │
# │                                          │  Connect ▼  │  │
# │                                          └─────────────┘  │
# └────────────────────────────────────────────────────────────┘
# ```
#
# **Paso 2:** Haz clic en la **flecha pequeña** junto al botón Connect y selecciona **"Change runtime type"** (Cambiar tipo de entorno de ejecución).
#
# **Paso 3:** En el cuadro de diálogo, selecciona **"T4 GPU"** y haz clic en **"Save"** (Guardar).
#
# ```
# ┌─────────────────────────────────────────┐
# │       Runtime type                      │
# │  ┌─────────────────────────────────┐    │
# │  │ Hardware accelerator            │    │
# │  │  ○ None (CPU only)              │    │
# │  │  ● T4 GPU        ← Seleccionar  │    │
# │  │  ○ A100 GPU                     │    │
# │  │  ○ TPU                          │    │
# │  └─────────────────────────────────┘    │
# │                                         │
# │            [ Cancel ]  [ Save ]         │
# └─────────────────────────────────────────┘
# ```
#
# **Paso 4:** Colab reiniciará la sesión con recursos GPU. Verás que ahora aparece **GPU RAM** además de RAM normal.
#
# **Paso 5:** Verifica que tienes GPU ejecutando `!nvidia-smi` (lo haremos más adelante en este notebook).
#
# ---
#
# ### ¿Qué es la GPU T4?
#
# La **Tesla T4** es una GPU fabricada por NVIDIA, diseñada específicamente para inteligencia artificial y machine learning en la nube.
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │                    NVIDIA TESLA T4                          │
# ├─────────────────────────────────────────────────────────────┤
# │  Memoria:        16 GB GDDR6                                │
# │  Núcleos CUDA:   2,560                                      │
# │  Tensor Cores:   320 (aceleran operaciones de IA)           │
# │  Arquitectura:   Turing (2018)                              │
# │  Uso típico:     Inferencia y entrenamiento de ML           │
# └─────────────────────────────────────────────────────────────┘
# ```
#
# **¿Por qué Google ofrece T4 gratis?**
# - Es una GPU eficiente en consumo de energía
# - Tiene un buen balance entre rendimiento y costo
# - Los 16 GB de memoria son suficientes para la mayoría de proyectos educativos
#
# **Comparación con tu laptop:**
#
# | Característica | Laptop típica | Google Colab T4 |
# |----------------|---------------|-----------------|
# | GPU | Integrada o gaming | Tesla T4 |
# | Memoria GPU | 2-8 GB | 16 GB |
# | Núcleos CUDA | 0-2,000 | 2,560 |
# | Costo | Tu electricidad | Gratis |
#
# Con la T4, nuestro entrenamiento de ResNet50 tardará ~20-25 minutos en lugar de horas.

# %% [markdown]
# ---
#
# ## ¿Qué es ResNet50?
#
# **ResNet** (Residual Network) es una arquitectura de CNN creada por Microsoft Research que ganó la competencia ImageNet en 2015. El "50" significa que tiene 50 capas de profundidad.
#
# ### El problema de las redes profundas
#
# Antes de ResNet, agregar más capas a una red neuronal eventualmente **empeoraba** los resultados. Esto se llama "vanishing gradient" (gradientes que desaparecen).
#
# ```
# RED TRADICIONAL PROFUNDA
#
# Entrada → [Capa 1] → [Capa 2] → ... → [Capa 50] → Salida
#                                            ↑
#                                     El gradiente llega
#                                     casi en CERO aquí
#                                     (no aprende nada)
# ```
#
#
# ### Transfer Learning
#
# No entrenamos ResNet desde cero. Usamos una versión **pre-entrenada en ImageNet** (1.2 millones de imágenes, 1000 categorías).
#
# ```
# TRANSFER LEARNING
#
# ┌─────────────────────────────────────────────────────────┐
# │                                                         │
# │   ImageNet (1.2M imágenes)    Nuestro dataset (7,591)   │
# │   ┌─────────────────────┐     ┌─────────────────────┐   │
# │   │ 🐕 🐈 🚗 🌸    ....│     │     👤 👤 👤       │   │
# │   │                     │     │   (rostros con edad)│   │
# │   └─────────────────────┘     └─────────────────────┘   │
# │              │                           │              │
# │              ▼                           ▼              │
# │   ResNet aprende:             Solo ajustamos las        │
# │   - Detectar bordes           últimas capas para        │
# │   - Reconocer texturas        predecir EDAD             │
# │   - Identificar formas                                  │
# │                                                         │
# └─────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ---
#
# ## Contexto del Proyecto
#
# La cadena de supermercados **Good Seed** quiere cumplir con las leyes sobre alcohol, verificando la edad de los clientes mediante cámaras en el área de pago.
#
# **Objetivo:** Construir un modelo que prediga la edad a partir de una foto con **MAE < 8 años**.

# %% [markdown]
# ---
#
# ## Estructura de este Notebook
#
# | Sección | ¿Dónde ejecutar? |
# |---------|------------------|
# | Carga de datos | Plataforma TripleTen O Google Colab |
# | EDA (Análisis exploratorio) | Plataforma TripleTen O Google Colab |
# | Definición de funciones | Plataforma TripleTen O Google Colab |
# | **Entrenamiento del modelo** | **Solo Google Colab (GPU)** |
# | Resultados y conclusiones | Plataforma TripleTen O Google Colab |

# %% [markdown]
# ---
#
# ## Inicialización y Carga de Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Detectar entorno y cargar datos
# - En Google Colab: descargar desde GitHub Release
# - En plataforma TripleTen: usar ruta estándar /datasets/faces/

try:
    # Intentar cargar desde la plataforma TripleTen
    path = '/datasets/faces/final_files/'
    labels = pd.read_csv('/datasets/faces/labels.csv')
    print("✓ Ejecutando en plataforma TripleTen")
    print(f"  Dataset cargado desde: /datasets/faces/")
    
except FileNotFoundError:
    # Estamos en Google Colab - descargar dataset
    print("✓ Ejecutando en Google Colab")
    print("  Descargando dataset desde GitHub...")
    
    # Descargar y extraer
    # !wget -q --show-progress https://github.com/HesusG/da-ds-notebook-solutions/releases/download/asset/faces_dataset.zip
    # !unzip -q faces_dataset.zip
    # !rm faces_dataset.zip
    
    # El zip extrae labels.csv y final_files/ en /content/
    path = '/content/final_files/'
    labels = pd.read_csv('/content/labels.csv')
    print(f"  Dataset extraído en: /content/")

print(f"\n📊 Total de imágenes: {len(labels)}")

# %%
# Vista previa de los datos
labels.head(10)

# %% [markdown]
# ---
#
# ## Análisis Exploratorio de Datos (EDA)

# %%
# Información general
labels.info()

# %%
# Estadísticas descriptivas
labels.describe()

# %%
# Distribución de edades
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histograma
axes[0].hist(labels['real_age'], bins=50, edgecolor='black', alpha=0.7, color='steelblue')
axes[0].set_xlabel('Edad')
axes[0].set_ylabel('Frecuencia')
axes[0].set_title('Distribución de Edades en el Dataset')
axes[0].axvline(labels['real_age'].mean(), color='red', linestyle='--', linewidth=2, label=f'Media: {labels["real_age"].mean():.1f}')
axes[0].axvline(labels['real_age'].median(), color='green', linestyle='--', linewidth=2, label=f'Mediana: {labels["real_age"].median():.1f}')
axes[0].legend()

# Box plot
axes[1].boxplot(labels['real_age'], vert=True)
axes[1].set_ylabel('Edad')
axes[1].set_title('Box Plot de Edades')

plt.tight_layout()
plt.show()

# %%
# Análisis de menores de edad (crítico para el objetivo del proyecto)
menores_18 = labels[labels['real_age'] < 18]
adultos = labels[labels['real_age'] >= 18]

print("=" * 50)
print("ANÁLISIS DE GRUPOS DE EDAD")
print("=" * 50)
print(f"\nMenores de 18 años: {len(menores_18):,} ({len(menores_18)/len(labels)*100:.1f}%)")
print(f"Adultos (18+):      {len(adultos):,} ({len(adultos)/len(labels)*100:.1f}%)")

# Desglose de adolescentes
print("\n" + "-" * 50)
print("Desglose de edades 11-17 (adolescentes):")
print("-" * 50)
adolescentes = labels[(labels['real_age'] >= 11) & (labels['real_age'] <= 17)]
print(adolescentes.groupby('real_age').size().to_string())
print(f"\nTotal adolescentes (11-17): {len(adolescentes)}")

# %%
# Vista previa de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)

sample_gen = train_datagen.flow_from_dataframe(
    dataframe=labels,
    directory=path,
    x_col='file_name',
    y_col='real_age',
    target_size=(224, 224),
    batch_size=16,
    class_mode='raw',
    seed=12345
)

features, target = next(sample_gen)

fig = plt.figure(figsize=(12, 8))
for i in range(16):
    ax = fig.add_subplot(4, 4, i+1)
    ax.imshow(features[i])
    ax.set_title(f'Edad: {int(target[i])}', fontsize=10)
    ax.axis('off')
plt.suptitle('Muestra de Imágenes del Dataset', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusiones del EDA
#
# | Métrica | Valor |
# |---------|-------|
# | Total imágenes | 7,591 |
# | Rango de edades | 1 - 100 años |
# | Edad media | ~31 años |
# | Edad mediana | ~29 años |
# | Menores de 18 | ~20% |
# | Adultos (18+) | ~80% |
#
# **Observación importante:** El dataset tiene **poca representación de menores de edad**, que son precisamente el grupo crítico para detectar en el contexto de venta de alcohol.

# %% [markdown]
# ---
#
# ## Parámetros del Modelo Explicados
#
# Antes de definir las funciones, entendamos los parámetros clave:
#
# | Parámetro | Valor | Explicación |
# |-----------|-------|-------------|
# | `rescale=1./255` | 1/255 | Normaliza píxeles de 0-255 a 0-1. Las redes neuronales funcionan mejor con valores pequeños. |
# | `target_size` | (224, 224) | Tamaño estándar para ResNet. Todas las imágenes se redimensionan a 224x224 píxeles. |
# | `batch_size` | 32 | Número de imágenes procesadas antes de actualizar los pesos. Mayor = más rápido pero más memoria. |
# | `validation_split` | 0.25 | 75% de datos para entrenar, 25% para validar. |
# | `class_mode='raw'` | 'raw' | Indica que es regresión (predecir número), no clasificación (predecir categoría). |
# | `epochs` | 20 | El modelo verá todo el dataset 20 veces. |
# | `learning_rate` | 0.0001 | Qué tan grandes son los "pasos" al ajustar pesos. Bajo para transfer learning. |
#
# ### ¿Qué es el Optimizador Adam?
#
# Adam ajusta los pesos de la red para minimizar el error. Imagina buscar el punto más bajo de una montaña con niebla:
#
# ```
#     Error
#       ▲
#       │   ╱╲
#       │  ╱  ╲     ╱╲
#       │ ╱    ╲   ╱  ╲
#       │╱      ╲_╱    ╲_____ Óptimo (menor error)
#       └───────────────────▶ Pesos
#
#       Adam adapta el tamaño del paso según el "terreno":
#       - Pasos grandes en pendientes suaves
#       - Pasos pequeños en zonas empinadas
# ```

# %% [markdown]
# ---
#
# ## Definición de Funciones del Modelo

# %%
def load_train(labels_df, image_dir_path):
    """
    Carga la parte de entrenamiento del conjunto de datos.

    Parámetros:
    - labels_df: DataFrame con las etiquetas (file_name y real_age)
    - image_dir_path: Ruta al directorio de las imágenes

    Retorna:
    - Generador de imágenes de entrenamiento (75% del dataset)
    """
    train_datagen = ImageDataGenerator(
        rescale=1./255,           # Normalizar píxeles: 0-255 → 0-1
        validation_split=0.25     # Reservar 25% para validación
    )

    train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=labels_df,
        directory=image_dir_path,
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),   # Tamaño requerido por ResNet
        batch_size=32,
        class_mode='raw',         # Regresión (no clasificación)
        subset='training',
        seed=12345
    )

    return train_gen_flow

# %%
def load_test(labels_df, image_dir_path):
    """
    Carga la parte de validación del conjunto de datos.

    Parámetros:
    - labels_df: DataFrame con las etiquetas (file_name y real_age)
    - image_dir_path: Ruta al directorio de las imágenes

    Retorna:
    - Generador de imágenes de validación (25% del dataset)
    """
    test_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=0.25
    )

    test_gen_flow = test_datagen.flow_from_dataframe(
        dataframe=labels_df,
        directory=image_dir_path,
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        subset='validation',
        seed=12345
    )

    return test_gen_flow

# %%
def create_model(input_shape=(224, 224, 3)):
    """
    Crea el modelo CNN usando ResNet50 pre-entrenado.
    
    Arquitectura:
    ┌─────────────────────────────────┐
    │  ResNet50 (sin capa final)      │  ← Extrae características de la imagen
    │  Pesos pre-entrenados ImageNet  │
    └─────────────────────────────────┘
                   │
                   ▼
    ┌─────────────────────────────────┐
    │  GlobalAveragePooling2D         │  ← Reduce (7,7,2048) → (2048,)
    └─────────────────────────────────┘
                   │
                   ▼
    ┌─────────────────────────────────┐
    │  Dense(1, activation='relu')    │  ← Predice la edad (número positivo)
    └─────────────────────────────────┘
    
    Retorna:
    - Modelo compilado listo para entrenar
    """
    from tensorflow.keras.applications.resnet import ResNet50
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
    from tensorflow.keras.optimizers import Adam
    
    # Cargar ResNet50 pre-entrenado
    backbone = ResNet50(
        input_shape=input_shape,
        weights='imagenet',       # Pesos de ImageNet (1.2M imágenes)
        include_top=False         # Sin la capa de clasificación original
    )
    
    # Construir modelo secuencial
    model = Sequential([
        backbone,
        GlobalAveragePooling2D(),
        Dense(1, activation='relu')  # ReLU porque la edad es siempre positiva
    ])
    
    # Compilar con Adam y métricas apropiadas
    model.compile(
        optimizer=Adam(learning_rate=0.0001),  # LR bajo para fine-tuning
        loss='mean_squared_error',              # Penaliza errores grandes
        metrics=['mae']                         # Error absoluto medio (interpretable)
    )
    
    return model

# %%
def train_model(model, train_data, test_data, batch_size=None, epochs=20,
                steps_per_epoch=None, validation_steps=None):
    """
    Entrena el modelo con los datos proporcionados.
    
    Parámetros:
    - model: Modelo a entrenar
    - train_data: Generador de datos de entrenamiento
    - test_data: Generador de datos de validación
    - epochs: Número de pasadas por el dataset (default: 20)
    
    Retorna:
    - Modelo entrenado
    """
    if steps_per_epoch is None:
        steps_per_epoch = len(train_data)
    if validation_steps is None:
        validation_steps = len(test_data)
    
    model.fit(
        train_data,
        validation_data=test_data,
        batch_size=batch_size,
        epochs=epochs,
        steps_per_epoch=steps_per_epoch,
        validation_steps=validation_steps,
        verbose=2
    )
    
    return model

# %% [markdown]
# ---
#
# <div style="background-color: #1a5f2a; padding: 20px; border-radius: 10px; margin: 20px 0; border-left: 5px solid #2ecc71;">
#     <h2 style="color: white; margin: 0;">⚡ SECCIÓN EXCLUSIVA DE GOOGLE COLAB</h2>
#     <p style="color: #ecf0f1; margin: 10px 0 0 0;">
#         Las siguientes celdas requieren GPU y deben ejecutarse en Google Colab.<br>
#         <strong>Instrucciones:</strong> Runtime → Change runtime type → T4 GPU
#     </p>
# </div>

# %%
# Verificar que tenemos GPU disponible
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("\nGPUs disponibles:")
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        print(f"  ✓ {gpu}")
else:
    print("  ✗ No se detectó GPU")
    print("  → Ve a Runtime → Change runtime type → T4 GPU")

# %%
# Información detallada de la GPU (solo funciona en Colab con GPU)
# !nvidia-smi

# %%
# Cargar datos de entrenamiento y validación
train_data = load_train(labels, path)
test_data = load_test(labels, path)

print(f"\nImágenes de entrenamiento: {train_data.samples:,}")
print(f"Imágenes de validación: {test_data.samples:,}")
print(f"Batches por época: {len(train_data)}")

# %%
# Crear el modelo
model = create_model(input_shape=(224, 224, 3))

print("\nResumen del modelo:")
model.summary()

# %%
# ENTRENAR EL MODELO
# Tiempo estimado: ~20-25 minutos con GPU T4

print("Iniciando entrenamiento...")
print("(Esto tomará aproximadamente 20-25 minutos con GPU T4)")
print("Tip: Expande la sección de lectura opcional mientras esperas\n")

model = train_model(
    model,
    train_data,
    test_data,
    epochs=20
)

print("\n" + "=" * 50)
print("ENTRENAMIENTO COMPLETADO")
print("=" * 50)

# %% [markdown]
# <details>
# <summary><strong>📚 Mientras entrena tu modelo: Profundizando en Redes Neuronales (~5 min de lectura)</strong></summary>
#
# ---
#
# ## 1. ¿Qué es una Neurona Artificial?
#
# Una neurona artificial es la unidad básica de una red neuronal. Recibe entradas, las multiplica por pesos, suma todo, y aplica una función de activación.
#
# ![Neurona Artificial](../local-assets/generated_images/01_neuron.png)
#
# **Analogía:** Imagina que eres un juez en un concurso de cocina:
# - **Entradas (x)** = Las calificaciones de diferentes aspectos (sabor, presentación, creatividad)
# - **Pesos (w)** = Qué tan importante es cada aspecto para ti
# - **Suma (Σ)** = Combinas todo en una puntuación total
# - **Activación** = Decides si el plato "pasa" o "no pasa"
#
# En el código, cuando escribes `Dense(1)`, estás creando exactamente esta neurona.
#
# ---
#
# ## 2. De Neurona a Red Neuronal
#
# Una red neuronal conecta muchas neuronas en capas. Cada capa transforma los datos de una forma diferente.
#
# ![Red Neuronal Multicapa](../local-assets/generated_images/02_neural_network.png)
#
# **¿Por qué "deep" learning?**
#
# "Deep" significa que hay muchas capas ocultas entre la entrada y la salida. ResNet50 tiene 50 capas, por eso puede aprender patrones muy complejos.
#
# Cuando ejecutas `model.summary()`, ves exactamente esta estructura: millones de parámetros (pesos) que la red ajusta durante el entrenamiento.
#
# ---
#
# ## 3. ¿Por Qué las CNNs Funcionan para Imágenes?
#
# Las Redes Neuronales Convolucionales (CNNs) procesan imágenes de forma jerárquica: primero detectan patrones simples, luego los combinan en patrones más complejos.
#
# ![Jerarquía de Capas CNN](../local-assets/generated_images/03_cnn_hierarchy.png)
#
# **Analogía del detective:**
# - **Capa 1:** Busca pistas pequeñas (líneas, bordes)
# - **Capa 2:** Combina pistas en patrones (texturas, gradientes)
# - **Capa 3:** Reconoce partes (ojos, nariz, boca)
# - **Salida:** Llega a una conclusión (edad estimada)
#
# Esta jerarquía es lo que hace a las CNNs tan poderosas para visión artificial.
#
# ---
#
# ## 4. La Revolución ResNet: Skip Connections
#
# Antes de 2015, agregar más capas a una red eventualmente empeoraba los resultados. ResNet resolvió esto con **skip connections** (conexiones de atajo).
#
# ![Bloque Residual ResNet](../local-assets/generated_images/04_resnet_block.png)
#
# **¿Por qué funcionan los skip connections?**
#
# El skip connection permite que la información "salte" las capas de procesamiento. Así:
# - Si las capas aprenden algo útil → se suma al atajo
# - Si las capas no aprenden nada → al menos pasa la información original
#
# **Analogía:** Es como tomar apuntes en clase. Si tus notas son buenas, las agregas al libro. Si son malas, al menos tienes el libro original.
#
# Resultado: Esto permitió entrenar redes de 50, 101, hasta 152 capas sin problemas.
#
# ---
#
# ## 5. Transfer Learning: Reutilizar Conocimiento
#
# En lugar de entrenar ResNet desde cero (lo cual requeriría millones de imágenes), usamos una versión ya entrenada en ImageNet y solo ajustamos la última capa.
#
# ![Transfer Learning](../local-assets/generated_images/05_transfer_learning.png)
#
# **¿Qué "sabe" ResNet de ImageNet?**
# - **Capas iniciales:** Bordes, líneas, gradientes (universal para cualquier imagen)
# - **Capas medias:** Texturas, patrones, formas básicas
# - **Capas finales:** Conceptos específicos (que reemplazamos para predecir edad)
#
# **Analogía del idioma:**
# - Entrenar desde cero = Aprender japonés sin saber ningún idioma
# - Transfer learning = Aprender japonés sabiendo chino (comparten caracteres)
#
# En nuestro código, `weights='imagenet'` carga estos conocimientos pre-aprendidos.
#
# ---
#
# ## 6. Aplicaciones Reales de CNNs
#
# Las CNNs están en todas partes:
#
# | Aplicación | Cómo funciona |
# |------------|---------------|
# | **Face ID (Apple)** | CNN detecta 30,000 puntos en tu rostro |
# | **Diagnóstico médico** | Detecta tumores en radiografías con 95% precisión |
# | **Tesla Autopilot** | 8 cámaras + CNNs identifican autos, peatones, señales |
# | **Filtros Instagram** | CNNs detectan rostro y aplican efectos en tiempo real |
# | **Google Photos** | Busca "perro" y encuentra todas tus fotos de perros |
#
# ---
#
# **¡Tu modelo ya casi termina de entrenar!** 🎉
#
# Ahora entiendes no solo *cómo* funciona, sino *por qué* funciona.
#
# </details>

# %% [markdown]
# ---
#
# ## Conclusiones
#
# ### Resultados Obtenidos
#
# - **MAE en validación:** ~6.1 años
# - **Objetivo:** MAE < 8 años → **CUMPLIDO** ✅
# - **Tiempo de entrenamiento:** ~20-25 minutos (GPU T4)
#
# ### ¿Qué significa un MAE de 6 años?
#
# El modelo predice la edad con un error promedio de 6 años. Por ejemplo:
# - Si predice 22 años, la edad real probablemente está entre 16-28 años
# - Hay margen de error en el límite de 18 años (mayoría de edad)
#
# ### Limitaciones del Modelo
#
# 1. **Desbalance de datos:** Solo ~20% son menores de 18 años
# 2. **Zona crítica:** Mayor incertidumbre entre 15-21 años
# 3. **Overfitting leve:** MAE de entrenamiento (~2.8) vs validación (~6.1)
#
# ### Recomendaciones para Mejorar
#
# 1. **Más datos de menores:** Recolectar más imágenes de personas 14-20 años
# 2. **Data augmentation:** Rotaciones, zoom, cambios de brillo
# 3. **Fine-tuning avanzado:** Descongelar capas superiores de ResNet
# 4. **Callbacks:** EarlyStopping y ReduceLROnPlateau

# %% [markdown]
# ---
#
# ## Conclusiones
#
# ### Resultados Obtenidos
#
# - **MAE en validación:** ~6.14 años
# - **Objetivo:** MAE < 8 años → **CUMPLIDO** ✅
# - **Tiempo de entrenamiento:** ~13 minutos (GPU T4)
#
# ### ¿Qué significa un MAE de 6 años?
#
# El modelo predice la edad con un error promedio de 6 años. Por ejemplo:
# - Si predice 22 años, la edad real probablemente está entre 16-28 años
# - Hay margen de error en el límite de 18 años (mayoría de edad)
#
# ### Limitaciones del Modelo
#
# 1. **Desbalance de datos:** Solo ~20% son menores de 18 años
# 2. **Zona crítica:** Mayor incertidumbre entre 15-21 años
# 3. **Overfitting leve:** MAE de entrenamiento (~1.8) vs validación (~6.1)
#
# ### Recomendaciones para Mejorar
#
# 1. **Más datos de menores:** Recolectar más imágenes de personas 14-20 años
# 2. **Data augmentation:** Rotaciones, zoom, cambios de brillo
# 3. **Fine-tuning avanzado:** Descongelar capas superiores de ResNet
# 4. **Callbacks:** EarlyStopping y ReduceLROnPlateau

# %% [markdown]
# ---
#
# ## Checklist del Proyecto
#
# - [x] Cargar imágenes desde la carpeta correcta
# - [x] Cargar etiquetas desde `labels.csv`
# - [x] Realizar EDA con visualizaciones
# - [x] Redimensionar imágenes (224x224)
# - [x] Normalizar píxeles (rescale 1/255)
# - [x] Usar ImageDataGenerator con flow_from_dataframe
# - [x] Configurar validation_split
# - [x] Usar transfer learning (ResNet50)
# - [x] Capa de salida para regresión (Dense 1)
# - [x] Entrenar por al menos 10 épocas
# - [x] **MAE < 8 en validación** ✅
