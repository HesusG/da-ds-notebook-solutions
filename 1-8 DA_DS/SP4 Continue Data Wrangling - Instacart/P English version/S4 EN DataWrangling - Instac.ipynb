# %% [markdown]
# # Fill up that cart!

# %% [markdown]
# # Introduction
#
# Instacart is a grocery delivery platform where customers can place a grocery order and have it delivered to them, similar to how Uber Eats and Door Dash work.
# The dataset we've provided for you has been modified from the original. We've reduced the size of the dataset so that your calculations run faster and we’ve introduced missing and duplicate values. We were also careful to preserve the distributions of the original data when we made our changes.
#
# You have three steps to complete. For each one of them, write a brief introduction stating how you intend to solve the step, and write intermediate explanatory paragraphs justifying your decisions as you advance in your solution. Also write a conclusion summarizing your findings and choices.

# %% [markdown]
# ## Data dictionary
#
# There are five tables in the dataset, and you’ll need to use all of them to do your data preprocessing and EDA. Below is a data dictionary that lists the columns in each table and describes that data that hold.
#
# - `instacart_orders.csv`: each row corresponds to one order on the Instacart app
#     - `'order_id'`: ID number that uniquely identifies each order
#     - `'user_id'`: ID number that uniquely identifies each customer account
#     - `'order_number'`: the number of times this customer has placed an order
#     - `'order_dow'`: day of the week that the order placed (0 is Sunday)
#     - `'order_hour_of_day'`: hour of the day that the order was placed
#     - `'days_since_prior_order'`: number of days since this customer placed their previous order
# - `products.csv`: each row corresponds to a unique product that customers can buy
#     - `'product_id'`: ID number that uniquely identifies each product
#     - `'product_name'`: name of the product
#     - `'aisle_id'`: ID number that uniquely identifies each grocery aisle category
#     - `'department_id'`: ID number that uniquely identifies each grocery department category
# - `order_products.csv`: each row corresponds to one item placed in an order
#     - `'order_id'`: ID number that uniquely identifies each order
#     - `'product_id'`: ID number that uniquely identifies each product
#     - `'add_to_cart_order'`: the sequential order in which each item was placed in the cart
#     - `'reordered'`: 0 if the customer has never ordered this product before, 1 if they have
# - `aisles.csv`
#     - `'aisle_id'`: ID number that uniquely identifies each grocery aisle category
#     - `'aisle'`: name of the aisle
# - `departments.csv`
#     - `'department_id'`: ID number that uniquely identifies each grocery department category
#     - `'department'`: name of the department

# %% [markdown]
# # Step 1. Data overview
#
# Read the data files (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv`, and `/datasets/order_products.csv`) with `pd.read_csv()` using the proper parameters in order to read the data correctly. Check the information for each DataFrame created.

# %% [markdown]
# ## Solution plan
#
# Write here your plan for Step 1. Data overview

# %%
# Import libraries

# %%
# read datasets into DataFrames

# %%
# print DataFrame information

# %%
# print DataFrame information

# %%
# print DataFrame information

# %%
# print DataFrame information

# %%
# print DataFrame information

# %% [markdown]
# ## Conclusions
#
# Write here your intermediate conclusions for Step 1. Data overview

# %% [markdown]
# # Step 2 Data preparation
#
# Preprocess the data by doing the following:
#
# - Verify and fix data types (e.g. make sure ID columns are integers)
# - Identify and fill in missing values
# - Identify and remove duplicate values
#
# Be sure to explain what types of missing and duplicate values you found, how you filled or removed them, why you used those methods, and why you think these missing and duplicate values may have been present in the dataset.

# %% [markdown]
# ## Solution plan
#
# Write here your plan for Step 2. Data preparation

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders

# %% [markdown]
# Do you have duplicates lines? If yes, what do they have in common?

# %%
# Based on your findings
# Check all orders placed Wednesday at 2:00 AM

# %% [markdown]
# What does this result suggest?

# %%
# Remove duplicated orders

# %%
# Double check for duplicated rows

# %%
# Double check for duplicated order IDs only

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicated rows

# %%
# Check for just duplicated product IDs

# %%
# Check for just duplicated product names (convert names to lowercase to compare better)

# %%
# Check for duplicated product names that aren't missing

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `departments` data frame

# %%
# Check for fully duplicate rows

# %%
# Check for just duplicate departments IDs

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `aisles` data frame

# %%
# Check for fully duplicate rows

# %%
# Check for just duplicate aisles IDs

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for fullly duplicate rows

# %%
# Double check for any other tricky duplicates

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ## Find and remove missing values
#
# From our work dealing with duplicate values, we noticed that we also have missing values to investigate:
#
# * The `'product_name'` column of the products table.
# * The `'days_since_prior_order'` column of the orders table.
# * The `'add_to_cart_order'` column of the order_products table.

# %% [markdown]
# ### `products` data frame

# %%
# Find missing values in the 'product_name' column

# %% [markdown]
# Briefly describe your findings are.

# %%
# Are all of the missing product names associated with aisle ID 100?

# %% [markdown]
# Briefly describe your findings are.

# %%
# Are all of the missing product names associated with department ID 21?

# %% [markdown]
# Briefly describe your findings are.

# %%
# Use the department and aisle tables to check out tdata for aisle ID 100 and depatrment ID 21

# %% [markdown]
# Briefly describe your findings are.

# %%
# Fill missing product names with 'Unknown'

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `orders` data frame

# %%
# Find missing values

# %%
# Are there any missing values where it's not a customer's first order?

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ### `order_products` data frame

# %%
# Find missing values

# %%
# What are the min and max values in this column?

# %% [markdown]
# Briefly describe your findings are.

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'

# %%
# Do all orders with missing values have more than 64 products?
# Group the orders with missing data by order id
# Count the number of 'product_id' on each order and check the minimum value of the count

# %% [markdown]
# Briefly describe your findings are.

# %%
# Replace missing values in the 'add_to_cart_order' column with 999 and convert column to integer type

# %% [markdown]
# Briefly describe your findings and what you've done with them.

# %% [markdown]
# ## Conclusions
#
# Write here your intermediate conclusions for Step 2. Data preparation

# %% [markdown]
# # Step 3 Data Analysis:
#
# Once the data is processed and ready for analysis, perform the following analysis:

# %% [markdown]
# # [A] Easy (must complete all to pass)
#
# 1. Verify that values in the `'order_hour_of_day'` and `'order_dow'` columns in the `orders` table are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6).
# 2. Create a plot that shows how many people place orders for each hour of the day.
# 3. Create a plot that shows what day of the week people shop for groceries.
# 4. Create a plot that shows how long people wait until placing their next order, and comment on the minimum and maximum values.

# %% [markdown]
# ### [A1] Verify that the values are sensible

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [A2] How many people place orders for each hour of the day?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [A4] How long do people wait until placing another order? Comment on the minimum and maximum values.

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# # [B] Medium (must complete all to pass)
#
# 1. Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the bar charts for both days on the same plot and describe the differences that you see.
# 2. Plot the distribution for the number of orders that customers place (e.g. how many customers placed only 1 order, how many placed only 2, how many only 3, and so on…)
# 3. What are the top 20 products that are ordered most frequently (display their id and name)?

# %% [markdown]
# ### [B1] Difference on Wednesdays and Saturdays for  `'order_hour_of_day'`. Plot the bar charts for both days and describe the differences.

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# # [C] Hard (must complete at least two to pass)
#
# 1. How many items do people typically buy in one order? What does the distribution look like?
# 2. What are the top 20 items that are reordered most frequently (display their names and product IDs)?
# 3. For each product, what proportion of its orders are reorders (create a table with columns for the product ID, product name, and reorder proportion)?
# 4. For each customer, what proportion of their products ordered are reorders?
# 5. What are the top 20 items that people put in their carts first (display the product IDs, product names, and number of times they were the first item added to the cart)?

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %% [markdown]
# Write here your conclusions

# %% [markdown]
# ### General conclusion for the project:
